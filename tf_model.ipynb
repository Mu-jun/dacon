# %%
import os
from glob import glob

import random
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

# %% [markdown]
# # tf input pipline
# ## tf.data.dataset 만들기

# %%
train_path = "./dataset/main_directory/"
test_path = "./dataset/test/"

INPUT_SHAPE = (224,224,3)
BATCH_SIZE = 32
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
def parse_image(filename):
    img = tf.io.read_file(filename)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img,INPUT_SHAPE[:2])
    return img

def make_dataset(filepaths,labels):
    filenames_ds = tf.data.Dataset.from_tensor_slices(filepaths)
    images_ds = filenames_ds.map(
        parse_image,
        num_parallel_calls=AUTOTUNE
    )
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    return ds

def configure_for_performance(ds):
    ds = ds.shuffle(buffer_size=1000)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.repeat()
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

# %%
classes = os.listdir(train_path)
num_classes = len(classes)
print("number of classes :", num_classes)

filenames = glob(train_path+'*/*')
num_images = len(filenames)
print("number of images :", num_images)

print(filenames[0])
print(filenames[0].split(os.sep)[-2])
print()

random.shuffle(filenames)
labels = [classes.index(fn.split(os.sep)[-2]) for fn in filenames]

print("data 5 preview")
for path,label in zip(filenames[:5],labels[:5]):
    print(path)
    print("class :",classes[label])
# Out:
# number of classes : 11
# number of images : 858
# ./dataset/main_directory\1\1_train_031.png
# 1
#
# data 5 preview
# ./dataset/main_directory\2\2_train_114.png
# class : 2
# ./dataset/main_directory\8\8_train_496.png
# class : 8
# ./dataset/main_directory\10-1\10-1_train_390.png
# class : 10-1
# ./dataset/main_directory\10-1\10-1_train_827.png
# class : 10-1
# ./dataset/main_directory\5\5_train_645.png
# class : 5

# %% [markdown]
# # 학습셋, 검증셋으로 나누기

# %%
train_x, val_x, train_y, val_y = train_test_split(
    filenames, labels, test_size=0.2,
    stratify=labels, random_state=1
)
num_train = len(train_x)
num_val = len(val_x)
print("number of training data :", num_train)
print("number of validation data :", num_val)

print("data 5 preview")
for path,label in zip(train_x[:5],train_y[:5]):
    print(path)
    print("class :",classes[label])
# Out:
# number of training data : 686
# number of validation data : 172
# data 5 preview
# ./dataset/main_directory\8\8_train_432.png
# class : 8
# ./dataset/main_directory\5\5_train_694.png
# class : 5
# ./dataset/main_directory\5\5_train_652.png
# class : 5
# ./dataset/main_directory\4\4_train_146.png
# class : 4
# ./dataset/main_directory\10-1\10-1_train_250.png
# class : 10-1

# %%
train_ds = make_dataset(train_x, train_y)

# %%
for img, label in train_ds.take(5):
    # print(img.numpy().shape)
    img = img.numpy()
    # print(img.min(), img.max())
    
    img = img.astype(np.uint8)
    idx = (label.numpy())
    
    plt.imshow(img), plt.axis('off')
    plt.title(classes[idx])
    plt.show()

# %%
val_ds = make_dataset(val_x, val_y)

# %%
# 모델 성능 높이기
train_ds = configure_for_performance(train_ds)
val_ds = configure_for_performance(val_ds)

# %% [markdown]
# # data augmentation layer
# ## evaluate() 또는 predict() 호출 시에는 자동으로 비활성화 된다.

# %%
data_augmentation = keras.Sequential([
    keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
    keras.layers.experimental.preprocessing.RandomTranslation(0.1,0.1),
])

# %% [markdown]
# # model

# %%
transfer_model = keras.applications.EfficientNetV2M(
    input_shape= INPUT_SHAPE,
    include_top= False,
    weights= 'imagenet',
)
transfer_model.trainable = False
transfer_model.summary()
# Out:
# Model: "efficientnetv2-m"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling_4 (Rescaling)        (None, 224, 224, 3)  0           ['input_5[0][0]']
#
#  stem_conv (Conv2D)             (None, 112, 112, 24  648         ['rescaling_4[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 112, 112, 24  96          ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 112, 112, 24  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 112, 112, 24  5184        ['stem_activation[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 112, 112, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1a_project_activation (Ac  (None, 112, 112, 24  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  block1a_add (Add)              (None, 112, 112, 24  0           ['block1a_project_activation[0][0
#                                 )                                ]',
#                                                                   'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 112, 112, 24  5184        ['block1a_add[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 112, 112, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_project_activation (Ac  (None, 112, 112, 24  0          ['block1b_project_bn[0][0]']
#  tivation)                      )
#
#  block1b_add (Add)              (None, 112, 112, 24  0           ['block1b_project_activation[0][0
#                                 )                                ]',
#                                                                   'block1a_add[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 112, 112, 24  5184        ['block1b_add[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 112, 112, 24  96         ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_project_activation (Ac  (None, 112, 112, 24  0          ['block1c_project_bn[0][0]']
#  tivation)                      )
#
#  block1c_add (Add)              (None, 112, 112, 24  0           ['block1c_project_activation[0][0
#                                 )                                ]',
#                                                                   'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 56, 56, 96)   20736       ['block1c_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 56, 56, 96)  384         ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 56, 56, 96)  0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_project_conv (Conv2D)  (None, 56, 56, 48)   4608        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  block2a_project_bn (BatchNorma  (None, 56, 56, 48)  192         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 56, 56, 192)  82944       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 56, 56, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 56, 56, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_project_conv (Conv2D)  (None, 56, 56, 48)   9216        ['block2b_expand_activation[0][0]
#                                                                  ']
#
#  block2b_project_bn (BatchNorma  (None, 56, 56, 48)  192         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_add (Add)              (None, 56, 56, 48)   0           ['block2b_project_bn[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 56, 56, 192)  82944       ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 56, 56, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 56, 56, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_project_conv (Conv2D)  (None, 56, 56, 48)   9216        ['block2c_expand_activation[0][0]
#                                                                  ']
#
#  block2c_project_bn (BatchNorma  (None, 56, 56, 48)  192         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_add (Add)              (None, 56, 56, 48)   0           ['block2c_project_bn[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 56, 56, 192)  82944       ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 56, 56, 192)  768        ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 56, 56, 192)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_project_conv (Conv2D)  (None, 56, 56, 48)   9216        ['block2d_expand_activation[0][0]
#                                                                  ']
#
#  block2d_project_bn (BatchNorma  (None, 56, 56, 48)  192         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_add (Add)              (None, 56, 56, 48)   0           ['block2d_project_bn[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 56, 56, 192)  82944       ['block2d_add[0][0]']
#
#  block2e_expand_bn (BatchNormal  (None, 56, 56, 192)  768        ['block2e_expand_conv[0][0]']
#  ization)
#
#  block2e_expand_activation (Act  (None, 56, 56, 192)  0          ['block2e_expand_bn[0][0]']
#  ivation)
#
#  block2e_project_conv (Conv2D)  (None, 56, 56, 48)   9216        ['block2e_expand_activation[0][0]
#                                                                  ']
#
#  block2e_project_bn (BatchNorma  (None, 56, 56, 48)  192         ['block2e_project_conv[0][0]']
#  lization)
#
#  block2e_add (Add)              (None, 56, 56, 48)   0           ['block2e_project_bn[0][0]',
#                                                                   'block2d_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 28, 28, 192)  82944       ['block2e_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 28, 28, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 28, 28, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 28, 28, 80)   15360       ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 28, 28, 80)  320         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 28, 28, 320)  230400      ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 28, 28, 320)  1280       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 28, 28, 320)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 28, 28, 80)   25600       ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 28, 28, 80)  320         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_add (Add)              (None, 28, 28, 80)   0           ['block3b_project_bn[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 28, 28, 320)  230400      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 28, 28, 320)  1280       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 28, 28, 320)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_project_conv (Conv2D)  (None, 28, 28, 80)   25600       ['block3c_expand_activation[0][0]
#                                                                  ']
#
#  block3c_project_bn (BatchNorma  (None, 28, 28, 80)  320         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_add (Add)              (None, 28, 28, 80)   0           ['block3c_project_bn[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 28, 28, 320)  230400      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 28, 28, 320)  1280       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 28, 28, 320)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_project_conv (Conv2D)  (None, 28, 28, 80)   25600       ['block3d_expand_activation[0][0]
#                                                                  ']
#
#  block3d_project_bn (BatchNorma  (None, 28, 28, 80)  320         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_add (Add)              (None, 28, 28, 80)   0           ['block3d_project_bn[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2D)   (None, 28, 28, 320)  230400      ['block3d_add[0][0]']
#
#  block3e_expand_bn (BatchNormal  (None, 28, 28, 320)  1280       ['block3e_expand_conv[0][0]']
#  ization)
#
#  block3e_expand_activation (Act  (None, 28, 28, 320)  0          ['block3e_expand_bn[0][0]']
#  ivation)
#
#  block3e_project_conv (Conv2D)  (None, 28, 28, 80)   25600       ['block3e_expand_activation[0][0]
#                                                                  ']
#
#  block3e_project_bn (BatchNorma  (None, 28, 28, 80)  320         ['block3e_project_conv[0][0]']
#  lization)
#
#  block3e_add (Add)              (None, 28, 28, 80)   0           ['block3e_project_bn[0][0]',
#                                                                   'block3d_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 28, 28, 320)  25600       ['block3e_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 28, 28, 320)  1280       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 28, 28, 320)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 14, 14, 320)  2880       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 14, 14, 320)  1280       ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 14, 14, 320)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 320)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 320)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 20)     6420        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 320)    6720        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 14, 14, 320)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 14, 14, 160)  51200       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 14, 14, 160)  640        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 14, 14, 640)  102400      ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 14, 14, 640)  2560       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 14, 14, 640)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 14, 14, 640)  5760       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 14, 14, 640)  2560       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 14, 14, 640)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 640)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 14, 14, 640)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 14, 14, 160)  102400      ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 14, 14, 160)  640        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_add (Add)              (None, 14, 14, 160)  0           ['block4b_project_bn[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 14, 14, 640)  102400      ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 14, 14, 640)  2560       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 14, 14, 640)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 14, 14, 640)  5760       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 14, 14, 640)  2560       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 14, 14, 640)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 640)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 14, 14, 640)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 14, 14, 160)  102400      ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 14, 14, 160)  640        ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_add (Add)              (None, 14, 14, 160)  0           ['block4c_project_bn[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 14, 14, 640)  102400      ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 14, 14, 640)  2560       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 14, 14, 640)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv2 (DepthwiseConv  (None, 14, 14, 640)  5760       ['block4d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4d_bn (BatchNormalization  (None, 14, 14, 640)  2560       ['block4d_dwconv2[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 14, 14, 640)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 640)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 14, 14, 640)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 14, 14, 160)  102400      ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 14, 14, 160)  640        ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_add (Add)              (None, 14, 14, 160)  0           ['block4d_project_bn[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 14, 14, 640)  102400      ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 14, 14, 640)  2560       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 14, 14, 640)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv2 (DepthwiseConv  (None, 14, 14, 640)  5760       ['block4e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4e_bn (BatchNormalization  (None, 14, 14, 640)  2560       ['block4e_dwconv2[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 14, 14, 640)  0          ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 640)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)   (None, 14, 14, 640)  0           ['block4e_activation[0][0]',
#                                                                   'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv2D)  (None, 14, 14, 160)  102400      ['block4e_se_excite[0][0]']
#
#  block4e_project_bn (BatchNorma  (None, 14, 14, 160)  640        ['block4e_project_conv[0][0]']
#  lization)
#
#  block4e_add (Add)              (None, 14, 14, 160)  0           ['block4e_project_bn[0][0]',
#                                                                   'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2D)   (None, 14, 14, 640)  102400      ['block4e_add[0][0]']
#
#  block4f_expand_bn (BatchNormal  (None, 14, 14, 640)  2560       ['block4f_expand_conv[0][0]']
#  ization)
#
#  block4f_expand_activation (Act  (None, 14, 14, 640)  0          ['block4f_expand_bn[0][0]']
#  ivation)
#
#  block4f_dwconv2 (DepthwiseConv  (None, 14, 14, 640)  5760       ['block4f_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4f_bn (BatchNormalization  (None, 14, 14, 640)  2560       ['block4f_dwconv2[0][0]']
#  )
#
#  block4f_activation (Activation  (None, 14, 14, 640)  0          ['block4f_bn[0][0]']
#  )
#
#  block4f_se_squeeze (GlobalAver  (None, 640)         0           ['block4f_activation[0][0]']
#  agePooling2D)
#
#  block4f_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4f_se_squeeze[0][0]']
#
#  block4f_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multiply)   (None, 14, 14, 640)  0           ['block4f_activation[0][0]',
#                                                                   'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv2D)  (None, 14, 14, 160)  102400      ['block4f_se_excite[0][0]']
#
#  block4f_project_bn (BatchNorma  (None, 14, 14, 160)  640        ['block4f_project_conv[0][0]']
#  lization)
#
#  block4f_add (Add)              (None, 14, 14, 160)  0           ['block4f_project_bn[0][0]',
#                                                                   'block4e_add[0][0]']
#
#  block4g_expand_conv (Conv2D)   (None, 14, 14, 640)  102400      ['block4f_add[0][0]']
#
#  block4g_expand_bn (BatchNormal  (None, 14, 14, 640)  2560       ['block4g_expand_conv[0][0]']
#  ization)
#
#  block4g_expand_activation (Act  (None, 14, 14, 640)  0          ['block4g_expand_bn[0][0]']
#  ivation)
#
#  block4g_dwconv2 (DepthwiseConv  (None, 14, 14, 640)  5760       ['block4g_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4g_bn (BatchNormalization  (None, 14, 14, 640)  2560       ['block4g_dwconv2[0][0]']
#  )
#
#  block4g_activation (Activation  (None, 14, 14, 640)  0          ['block4g_bn[0][0]']
#  )
#
#  block4g_se_squeeze (GlobalAver  (None, 640)         0           ['block4g_activation[0][0]']
#  agePooling2D)
#
#  block4g_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4g_se_squeeze[0][0]']
#
#  block4g_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4g_se_reshape[0][0]']
#
#  block4g_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4g_se_reduce[0][0]']
#
#  block4g_se_excite (Multiply)   (None, 14, 14, 640)  0           ['block4g_activation[0][0]',
#                                                                   'block4g_se_expand[0][0]']
#
#  block4g_project_conv (Conv2D)  (None, 14, 14, 160)  102400      ['block4g_se_excite[0][0]']
#
#  block4g_project_bn (BatchNorma  (None, 14, 14, 160)  640        ['block4g_project_conv[0][0]']
#  lization)
#
#  block4g_add (Add)              (None, 14, 14, 160)  0           ['block4g_project_bn[0][0]',
#                                                                   'block4f_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 14, 14, 960)  153600      ['block4g_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 14, 14, 960)  3840       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 14, 14, 960)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
# ...
#
#  block7a_project_bn (BatchNorma  (None, 7, 7, 512)   2048        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 7, 7, 3072)   1572864     ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 7, 7, 3072)  12288       ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 7, 7, 3072)  0           ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv2 (DepthwiseConv  (None, 7, 7, 3072)  27648       ['block7b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block7b_bn (BatchNormalization  (None, 7, 7, 3072)  12288       ['block7b_dwconv2[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 7, 7, 3072)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 3072)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 7, 7, 3072)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 7, 7, 512)    1572864     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 7, 7, 512)   2048        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_add (Add)              (None, 7, 7, 512)    0           ['block7b_project_bn[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 7, 7, 3072)   1572864     ['block7b_add[0][0]']
#
#  block7c_expand_bn (BatchNormal  (None, 7, 7, 3072)  12288       ['block7c_expand_conv[0][0]']
#  ization)
#
#  block7c_expand_activation (Act  (None, 7, 7, 3072)  0           ['block7c_expand_bn[0][0]']
#  ivation)
#
#  block7c_dwconv2 (DepthwiseConv  (None, 7, 7, 3072)  27648       ['block7c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block7c_bn (BatchNormalization  (None, 7, 7, 3072)  12288       ['block7c_dwconv2[0][0]']
#  )
#
#  block7c_activation (Activation  (None, 7, 7, 3072)  0           ['block7c_bn[0][0]']
#  )
#
#  block7c_se_squeeze (GlobalAver  (None, 3072)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 7, 7, 3072)   0           ['block7c_activation[0][0]',
#                                                                   'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 7, 7, 512)    1572864     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 7, 7, 512)   2048        ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_add (Add)              (None, 7, 7, 512)    0           ['block7c_project_bn[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2D)   (None, 7, 7, 3072)   1572864     ['block7c_add[0][0]']
#
#  block7d_expand_bn (BatchNormal  (None, 7, 7, 3072)  12288       ['block7d_expand_conv[0][0]']
#  ization)
#
#  block7d_expand_activation (Act  (None, 7, 7, 3072)  0           ['block7d_expand_bn[0][0]']
#  ivation)
#
#  block7d_dwconv2 (DepthwiseConv  (None, 7, 7, 3072)  27648       ['block7d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block7d_bn (BatchNormalization  (None, 7, 7, 3072)  12288       ['block7d_dwconv2[0][0]']
#  )
#
#  block7d_activation (Activation  (None, 7, 7, 3072)  0           ['block7d_bn[0][0]']
#  )
#
#  block7d_se_squeeze (GlobalAver  (None, 3072)        0           ['block7d_activation[0][0]']
#  agePooling2D)
#
#  block7d_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7d_se_squeeze[0][0]']
#
#  block7d_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multiply)   (None, 7, 7, 3072)   0           ['block7d_activation[0][0]',
#                                                                   'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv2D)  (None, 7, 7, 512)    1572864     ['block7d_se_excite[0][0]']
#
#  block7d_project_bn (BatchNorma  (None, 7, 7, 512)   2048        ['block7d_project_conv[0][0]']
#  lization)
#
#  block7d_add (Add)              (None, 7, 7, 512)    0           ['block7d_project_bn[0][0]',
#                                                                   'block7c_add[0][0]']
#
#  block7e_expand_conv (Conv2D)   (None, 7, 7, 3072)   1572864     ['block7d_add[0][0]']
#
#  block7e_expand_bn (BatchNormal  (None, 7, 7, 3072)  12288       ['block7e_expand_conv[0][0]']
#  ization)
#
#  block7e_expand_activation (Act  (None, 7, 7, 3072)  0           ['block7e_expand_bn[0][0]']
#  ivation)
#
#  block7e_dwconv2 (DepthwiseConv  (None, 7, 7, 3072)  27648       ['block7e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block7e_bn (BatchNormalization  (None, 7, 7, 3072)  12288       ['block7e_dwconv2[0][0]']
#  )
#
#  block7e_activation (Activation  (None, 7, 7, 3072)  0           ['block7e_bn[0][0]']
#  )
#
#  block7e_se_squeeze (GlobalAver  (None, 3072)        0           ['block7e_activation[0][0]']
#  agePooling2D)
#
#  block7e_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7e_se_squeeze[0][0]']
#
#  block7e_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7e_se_reshape[0][0]']
#
#  block7e_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7e_se_reduce[0][0]']
#
#  block7e_se_excite (Multiply)   (None, 7, 7, 3072)   0           ['block7e_activation[0][0]',
#                                                                   'block7e_se_expand[0][0]']
#
#  block7e_project_conv (Conv2D)  (None, 7, 7, 512)    1572864     ['block7e_se_excite[0][0]']
#
#  block7e_project_bn (BatchNorma  (None, 7, 7, 512)   2048        ['block7e_project_conv[0][0]']
#  lization)
#
#  block7e_add (Add)              (None, 7, 7, 512)    0           ['block7e_project_bn[0][0]',
#                                                                   'block7d_add[0][0]']
#
#  top_conv (Conv2D)              (None, 7, 7, 1280)   655360      ['block7e_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 7, 7, 1280)   5120        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 7, 7, 1280)   0           ['top_bn[0][0]']
#
# ==================================================================================================
# Total params: 53,150,388
# Trainable params: 0
# Non-trainable params: 53,150,388
# __________________________________________________________________________________________________

# %%
finetune_model = keras.Sequential([
    keras.Input(shape=INPUT_SHAPE),
    data_augmentation,
    keras.layers.experimental.preprocessing.Rescaling(1./255),
    transfer_model,
    keras.layers.Flatten(),
    keras.layers.Dense(num_classes, activation='softmax')
])
finetune_model.summary()

finetune_model.compile(loss='sparse_categorical_crossentropy',
                      optimizer=keras.optimizers.Adam(learning_rate=0.0002),
                       metrics='accuracy')
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 224, 224, 3)       0
#
#  rescaling_5 (Rescaling)     (None, 224, 224, 3)       0
#
#  efficientnetv2-m (Functiona  (None, 7, 7, 1280)       53150388
#  l)
#
#  flatten_2 (Flatten)         (None, 62720)             0
#
#  dense_2 (Dense)             (None, 11)                689931
#
# =================================================================
# Total params: 53,840,319
# Trainable params: 689,931
# Non-trainable params: 53,150,388
# _________________________________________________________________

# %%
for batch in train_ds.take(1):
    for i in range(5):
        img = batch[0][i]
        # print(img.numpy().shape)
        img = img.numpy()
        # print(img.min(), img.max())
        
        img = img.astype(np.uint8)
        
        label = batch[1][i]
        idx = (label.numpy())
        
        plt.imshow(img), plt.axis('off')
        plt.title(classes[idx])
        plt.show()

# %%
train_step = num_train//BATCH_SIZE
val_step = num_val//BATCH_SIZE

tf.random.set_seed(10)

hist = finetune_model.fit(
    train_ds, epochs=1,
    steps_per_epoch=train_step,
    validation_data=val_ds,
    validation_steps=val_step
)
# Out:
# 21/21 [==============================] - ETA: 0s - loss: 5.1033 - accuracy: 0.0952
